# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaswithagadde/Python_Projects/blob/main/GuessTheNumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
easy_attempts = 10
hard_attempts = 5
def set_difficulty(level):
  if level == "easy":
    return easy_attempts
  else:
    return hard_attempts
def check_answer(guessed_number,answer,attempts):
  if guessed_number < answer:
    print("Your answer was too low")
    return attempts - 1
  elif guessed_number > answer:
    print("Your answer was too high")
    return attempts - 1
  else:
    print(f"You got it! The answer was {answer}")
    return 0
def game():
  print("Let me think of a number between 1 to 50")
  answer = random.randint(1,50)
  level = input("Choose level of difficulty(easy or hard) : ")
  attempts=set_difficulty(level)
  guessed_number = 0
  while guessed_number != answer and attempts > 0:
    print(f"You have {attempts} attempts remaining to guess the number")
    try:
      guessed_number = int(input("Make a guess : "))
    except ValueError:
      print("Invalid input. Please enter a number.")
      continue

    if guessed_number != answer:
        attempts=check_answer(guessed_number,answer,attempts)
    else:
        check_answer(guessed_number,answer,attempts)
        attempts = 0

    if attempts == 0 and guessed_number != answer:
      print("You have run out of guesses, you lose")
      print(f"The correct answer was {answer}")
    elif guessed_number != answer:
      print("Guess again")

game()
# Out:
# Let me think of a number between 1 to 50
# Choose level of difficulty(easy or hard) : hard
# You have 5 attempts remaining to guess the number
# Make a guess : 35
# Your answer was too high
# Guess again
# You have 4 attempts remaining to guess the number
# Make a guess : 20
# Your answer was too low
# Guess again
# You have 3 attempts remaining to guess the number
# Make a guess : 47
# Your answer was too high
# Guess again
# You have 2 attempts remaining to guess the number
# Make a guess : 27
# Your answer was too high
# Guess again
# You have 1 attempts remaining to guess the number
# Make a guess : 23
# Your answer was too high
# You have run out of guesses, you lose
# The correct answer was 21
